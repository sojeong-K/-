# %% [markdown]
# # 데이터분석 프로그래밍 중간고사

# %% [markdown]
# ## 문제 1(35점 - 하나당 5점)
#
# ### 다음의 문제를 읽고 해당 코드를 작성하시오.
#
# #### 1. 다음 소스 코드를 완성하여 확장자가 .jpg, .png인 이미지 파일만 출력되게 만드세요. 여기서는 람다 표현식을 사용해야 하며 출력 결과는 리스트 형태라야 합니다. 람다 표현식에서 확장자를 검사할 때는 문자열 메서드를 활용하세요.

# %%
# 이 부분은 건드리지 말것
files = ['font', '1.png', '10.jpg', '11.gif', '2.jpg', '3.png', 'table.xslx', 'spec.docx']
 
# 풀이
print(list(filter(lambda x: x.find('.jpg') != -1 or x.find('.png') != -1, files)))
print(list(filter(lambda x: x.endswith('.jpg') or x.endswith('.png'), files))) #endswith를 사용
print([x for x in files if x.endswith('.jpg') or x.endswith('.png')]) #list comprehension 사용
# Out:
# ['1.png', '10.jpg', '2.jpg', '3.png']
# ['1.png', '10.jpg', '2.jpg', '3.png']
# ['1.png', '10.jpg', '2.jpg', '3.png']

# %% [markdown]
# ####  2. 다음 소스 코드를 완성하여 리스트 a에 들어있는 문자열 중에서 길이가 5인 것들만 리스트 형태로 출력되게 만드세요(리스트 표현식 사용).

# %%
# 이 부분은 건드리지 말것
a = ['alpha', 'bravo', 'charlie', 'delta', 'echo', 'foxtrot', 'golf', 'hotel', 'india']

# 풀이
b = [i for i in a if len(i) == 5]
 
print(b)
# Out:
# ['alpha', 'bravo', 'delta', 'hotel', 'india']

# %% [markdown]
# #### 3. 다음 소스 코드를 완성하여 파일 경로에서 파일명만 출력되게 만드세요. 단, 경로에서 폴더의 깊이가 달라지더라도 파일명만 출력할 수 있어야 합니다.

# %%
# 이 부분은 건드리지 말것
path = 'C:\\Users\\dojang\\AppData\\Local\\Programs\\Python\\Python36-32\\python.exe'
## 풀이
x = path.split('\\')
filename = x[-1]
# 또는
x = path.split('\\')
x.reverse()
filename = x[0]
# 또는
filename = path[path.rfind('\\') + 1:]

                                      
# 이 부분은 건드리지 말것 
print(filename)
# Out:
# python.exe

# %% [markdown]
# #### 4. 문자열을 입력받아 각 글자의 빈도수를 세어보시오.

# %%
## 이 부분은 건드리지 말것 
string=input("문자열을 입력하시오: ")
countTable={}
## 풀이
for letter in string:
    countTable[letter]=countTable.get(letter,0)+1 # get의 두번째 인수로 해당 키가 없을때 디폴트값을 넘길 수 있다.
print(countTable)

## 정렬하기
letter_items=list(countTable.items())
letter_items.sort()
print(letter_items)
# Out:
# 문자열을 입력하시오: aa b c ddd
# {'a': 2, ' ': 3, 'b': 1, 'c': 1, 'd': 3}
# [(' ', 3), ('a', 2), ('b', 1), ('c', 1), ('d', 3)]

# %% [markdown]
# #### 5. 문자열을 입력받아 머리글자어 (acronym)을 만들어보세요.

# %%
## 이 부분은 건드리지 말것
phrase=input("문자열을 입력하시오:")
acronym=""
# 풀이
for word in phrase.upper().split():
    acronym+=word[0] # 각 단어의 첫글자만을 추출하여 하나의 문자열로 합친다.
print(acronym)
# Out:
# 문자열을 입력하시오:Hello The WOrld
# HTW

# %% [markdown]
# #### 6. 문자열 안에 있는 문자의 개수, 숫자의 개수, 공백의 개수를 계산하는 프로그램을 작성하여 보자.
#
# 실행결과
#
# <pre>
# 문자열을 입력하시오: A picture is worth a thousand words.
# {'digit':0, 'spaces':6, 'alphas':29}
# </pre>

# %%
## 이 부분은 건드리지 말것
sentence=input("문자열을 입력하시오: ")
table={"alphas":0, "digits":0, "spaces":0}

## 풀이
for i in sentence:
    if i.isalpha():
        table["alphas"]+=1
    if i.isdigit():
        table["digits"]+=1
    if i.isspace():
        table["spaces"]+=1

print(table)
# Out:
# 문자열을 입력하시오: aaa t t i11
# {'alphas': 6, 'digits': 2, 'spaces': 3}

# %% [markdown]
# #### 7. 표준 입력으로 문자열이 입력됩니다. 입력된 문자열에서 'the'의 개수를 출력하는 프로그램을 만드세요(input에서 안내 문자열은 출력하지 않아야 합니다). 단, 모든 문자가 소문자인 'the'만 찾으면 되며 'them', 'there', 'their' 등은 포함하지 않아야 합니다.

# %%
#text = input()
text = '''the grown-ups' response, this time, was
to advise me to lay aside my drawings of boa constrictors,
whether from the inside or the outside, and devote myself
instead to geography, history, arithmetic, and grammar.
That is why, at the, age of six, I gave up what might have
been a magnificent career as a painter. I had been disheartened
by the failure of my Drawing Number One and my Drawing Number Two.
Grown-ups never understand anything by themselves, and it is tiresome
for children to be always and forever explaining things to the.'''
cnt = 0
for word in text.split():
    if word.strip(',.') == 'the':
        cnt += 1
print(cnt)
# Out:
# 6

# %% [markdown]
# #### 8. dictionary comprehension 으로 문제를 풀어보세요.

# %%
## 8.1 주어진 단어의 알파벳 갯수를 세어보시오.

word = "Apple"

d = {letter : word.count(letter) for letter in word}

print(d)
# Out:
# {'A': 1, 'p': 2, 'l': 1, 'e': 1}

# %%
## 8.2 email 부분만 소문자로 변경하시오. 

d = {'JOHN' : 'JOHN@GMAIL.COM', 'tom':'tom@Gmail.com'}
output = {k.capitalize():v.lower() for k,v in d.items()}
print(output)
# Out:
# {'John': 'john@gmail.com', 'Tom': 'tom@gmail.com'}

# %% [markdown]
# #### 9. zip 연습해보기
# 다음 2개의 리스트를 zip()과 dict()를 이용하여 dictionary로 변경해보세요

# %%
a=["lucy", "kang", "kim"]
b=["101", "202", "303"]
ab=zip(a,b)
dab=dict(ab)
print(dab)
# Out:
# {'lucy': '101', 'kang': '202', 'kim': '303'}

# %% [markdown]
# ## 문제 2(15점)
#
# ### 전화번호부
#
# 오늘도 별로 할일은 없이 밥 얻어먹으러 출근하는 윤승식 조교는 데이터분석 프로그래밍 중간고사 문제 아이디어를 신민철 연구원에게 말하기 위해 스마트폰 연락처 어플을 켰습니다.
#
# ***띠용?***
#
# 본인이 생각한 아이디어보다 전화번호부를 만들고, 연락처 검색 함수를 만드는게 더 재미있을 것 같다는 생각이 들었습니다. 정말 재미있는 문제인지 한번 풀어보도록 합시다
#
# ##### 연락처
# - 윤승식 : 010-3348-2859
# - 허준 : 010-7708-5617
# - 신민철 : 010-4729-8241
#
# > ###### 요구사항
# > 1. 위에 제시된 연락처만 이용하여 적절한 자료형을 이용하여 만들어주세요.(이름 중복 등은 고려하지 않도록 합니다)
# > 2. 연락처에 기록된 전화번호를 검색하는 contact_search() 함수를 만들어주세요. 함수의 결과물로 전화번호를 **리턴** 할 수 있도록 해주세요
# > 3. 해당 함수를 통해 연락처를 검색할 때, 이름의 일부만 입력해도 검색이 가능하도록 해 주세요.
#
# >    *예시: 준 -> 010-7708-5617, 신민철 -> 010-4729-8241, 윤 -> 010-3348-2859*

# %%
phone = {"윤승식":"010-3348-2859", "허준":"010-7708-5617", "신민철":"010-4729-8241"}
def contact_search(txt, phone):
    ans = []
    for key, value in phone.items():
        if txt in key:
            ans.append(value)
    return ans

# %%
print(contact_search("준", phone))
print(contact_search("신민철", phone))
print(contact_search("윤", phone))
# Out:
# ['010-7708-5617']
# ['010-4729-8241']
# ['010-3348-2859']

# %% [markdown]
# ## 문제 3(20점)
#
# ### 스키테일 암호
#
# ![image.png](attachment:image.png)
#
# 고대 그리스의 역사학자 플루타르크에 따르면 약 2,500년 그리스 지역의 옛 나라인 스파르타에서는 전쟁터에 나가있는 군대에 비밀메시지를 전할 때 암호를 그때 당시로서는 아무나 쉽게 암호문을 열어 볼수 없는, 아주 교묘하고도 획기적인 방법이었다. 이때 사용한 암호화방법은 스키테일(Scytale)암호라 하고 당시의 전쟁터에선 다음과 같은 방법으로 암호화하였다.
#
# 1. 전쟁터에 나갈 군대와 본국에 남아있는 정부는 각자, 스키테일(Scytale)이라고 하는 굵기의 원통형 막대기를 나누어 갖는다.
# 2. 비밀리에 보내야 할 메시지가 생기면, 본국 정부의 암호 담당자는 스키테일에 가느다란 양피지 리본을 위에서 아래로 감은 다음 옆으로 메시지를 적는다.
# 3. 리본을 풀어내어 펼치면 메시지의 내용은 아무나 읽을 수 없게 된다..
# 4. 전쟁터에 나가있는 오로지 같은 굵기의 원통막대기를 가진 사람만이 메시지를 읽을 수 있다.
#
# 스키테일 암호를 만드는 방법은 간단합니다. 메시지의 간격(n)을 설정하고, 그 사이에 의미없는 문자열을 삽입하면 되는 것이죠.
#
# 윤승식 연구원은 여자친구와의 비밀 메시지를 위해 메시지의 간격을 설정하고, 스키테일 암호를 이용하기로 결정하였습니다.
#
# 자, 이제 윤승식 연구원을 위해 간격을 정해주면 스키테일 암호문을 만들어내는 함수 encrypt()와, 이런 암호문을 해독하는 함수 decrypt()를 작성해 봅시다
#
# > ###### 요구사항
# > 1. 문자열과, 막대기의 굵기를 입력받아 스키테일 암호문을 암호화하는 함수 encrypt(string, n)과, 스키테일 암호문을 풀어내는 함수 decrypt(string, n)을 작성하세요.
# > 2. 사이에 집어넣을 임의의 문자열은 rand_str 함수를 이용하여 생성해주세요.
# > 3. 함수의 결과물로 string을 return해주세요.

# %%
# 이부분은 건드리지 말것, 한번 실행하고 문제 풀기
import random

character = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ"
def rand_str(length, characters=character):
    """
    rand_str(length, characters)
    characters에 지정되어 있는 문자열을 임의로 추출하여 length 길이만큼 추출해줍니다.
    characters를 지정하지 않을 시 기본값으로 영어 알파벳 대,소문자에서 임의의 문자를 추출합니다.
    """
    #return "".join([random.choice(characters) for _ in range(length)])
    return "".join(random.choices(characters, k=length))

# %%
rand_str(30)
# Out:
# 'QkQTKgpGntHeiufNdfQBrEoybjWBtz'

# %%
def encrypt(string, n):
    message=""
    for i in range(0,len(string)):
        message+=string[i]
        message+=rand_str(n)
    return message

def decrypt(string, n):
    message=""
    for i in range(0,len(string), n+1):
        message+=string[i]
    return message

# %%
enc = encrypt("ManchesterUnited", 2)
dec = decrypt(enc, 2)

print(enc)
print(dec)
# Out:
# MebaOunAtcdbhtueHtsMttBAeYwryuUoZnGbifhtFAeDKdcs
# ManchesterUnited

# %% [markdown]
# ## 문제 4(15점)
#
# ### 정건용바보 5행시 대회
#
# 오늘도 즐거운 다산관 508-2호 경영빅데이터센터, 오늘의 주제는 정건용바보로 5행시 짓기 입니다. 짝짝짝 :)
#
# 정 : 정건용!
#
# 건 : 건드리면 안될 사람을 건드렸다.
#
# 용 : 용용 죽겠지?
#
# 바 : 바보야 이거 누가냈게?
#
# 보 : 보고 화내지마
#
# 5행시를 넣으면(적절한 구조를 생각해서 파라미터로 넣으세요) 첫글자를 확인해서 "정건용바보"가 맞는지 확인하는 check5() 함수를 만들어주세요. 정건용바보가 맞다면 True, 아니면 False를 반환하도록 합니다.
#
# **위에 있는 시 말고, 다른 시를 만들어서 검사할 수 있도록 합니다. 우리 건용이는 소중하니까요!**

# %%
def check5(txt):
    for i in txt:
        first = input("%s: " %i)
        if first[0] != i:
            return False
    return True

# %% [markdown]
# ## 문제 5(15점)
# ### 승식이의 전동킥보드는 세계제일?
#
# ![image.png](attachment:image.png)
# <center>사진설명 : 출근하는 윤승식 조교, 여러분은 킥보드 탈때 핸드폰 쓰지 마세요!</center>
#
# 윤승식 조교의 잇템! 전동킥보드를 완충하는 시간은 6시간입니다.
#
# 승식이의 킥보드는 완충 시, 30km를 갈 수 있습니다.
#
# 승식이가 가야하는 거리 A와 왕복 여부를 입력받고 이에 필요한 충전 시간을 계산하는 함수 kickboard()를 만들어봅시다.
#
# **기본값은 "편도" 입니다.**
#
# 이때, 최대거리 이상 입력할 경우, "킥보드로 갈 수 없습니다" 라는 메시지를 출력하고, return은 None으로 합니다.

# %%
def kickboard():
    dist = input("가야하는 거리를 입력하시오(km): ")
    wang = input("왕복여부를 입력하시오(Y/N): ")
    if wang.upper() == "Y":
        wang=2
    else:
        wang=1
        
    if float(dist)*wang > 30:
        print("킥보드로 갈 수 없습니다.")
        return None
    else:
        return float(dist)*wang*6/30

# %%
kickboard()
# Out:
# 가야하는 거리를 입력하시오(km): 100
# 왕복여부를 입력하시오(Y/N): N
# 킥보드로 갈 수 없습니다.
